# %%
# from https://www.youtube.com/watch?v=xgDs0scjuuQ
# realization = test_train_split requires inputs of ARRAYS not dataframes

import numpy as np
import pandas as pd

data_url = "https://raw.githubusercontent.com/harshitroy2605/splitting-dataset-into-test-and-train/master/cars.csv"
df=pd.read_csv(data_url,delimiter=';')

df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
df.shape
# Out:
# (407, 9)

# %%
column_names= df.columns
column_names
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
features = column_names[1:]
label = column_names[0]
display(features, label)
# Out:
# Index(['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')
# 'Car'

# %%
# in amii this is often referred to as the features
#independent=df.iloc[1:,1:0].values
independent = df[features].values
independent
# Out:
# array([['DOUBLE', 'INT', 'DOUBLE', ..., 'DOUBLE', 'INT', 'CAT'],
#        ['18.0', '8', '307.0', ..., '12.0', '70', 'US'],
#        ['15.0', '8', '350.0', ..., '11.5', '70', 'US'],
#        ...,
#        ['32.0', '4', '135.0', ..., '11.6', '82', 'US'],
#        ['28.0', '4', '120.0', ..., '18.6', '82', 'US'],
#        ['31.0', '4', '119.0', ..., '19.4', '82', 'US']], dtype=object)

# %%
# in amii this is often referred to as the label
#dependent=df.iloc[1:,9:].values
dependent = df[label].values
dependent
# Out:
# array(['STRING', 'Chevrolet Chevelle Malibu', 'Buick Skylark 320',
#        'Plymouth Satellite', 'AMC Rebel SST', 'Ford Torino',
#        'Ford Galaxie 500', 'Chevrolet Impala', 'Plymouth Fury iii',
#        'Pontiac Catalina', 'AMC Ambassador DPL', 'Citroen DS-21 Pallas',
#        'Chevrolet Chevelle Concours (sw)', 'Ford Torino (sw)',
#        'Plymouth Satellite (sw)', 'AMC Rebel SST (sw)',
#        'Dodge Challenger SE', "Plymouth 'Cuda 340",
#        'Ford Mustang Boss 302', 'Chevrolet Monte Carlo',
#        'Buick Estate Wagon (sw)', 'Toyota Corolla Mark ii',
#        'Plymouth Duster', 'AMC Hornet', 'Ford Maverick', 'Datsun PL510',
#        'Volkswagen 1131 Deluxe Sedan', 'Peugeot 504', 'Audi 100 LS',
#        'Saab 99e', 'BMW 2002', 'AMC Gremlin', 'Ford F250', 'Chevy C20',
#        'Dodge D200', 'Hi 1200D', 'Datsun PL510', 'Chevrolet Vega 2300',
#        'Toyota Corolla', 'Ford Pinto', 'Volkswagen Super Beetle 117',
#        'AMC Gremlin', 'Plymouth Satellite Custom',
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.2,random_state=0)

x_train
# Out:
# array([['26.0', '4', '79.00', ..., '15.5', '74', 'Europe'],
#        ['23.0', '8', '350.0', ..., '17.4', '79', 'US'],
#        ['11.0', '8', '429.0', ..., '11.0', '72', 'US'],
#        ...,
#        ['21.0', '4', '140.0', ..., '19.5', '73', 'US'],
#        ['14.0', '8', '400.0', ..., '11.5', '71', 'US'],
#        ['21.0', '6', '231.0', ..., '15.0', '75', 'US']], dtype=object)

# %%
# count array items in x_train array
x_train.size
# Out:
# 2600

# %%
x_test
# Out:
# array([['20.5', '6', '200.0', '95.00', '3155.', '18.2', '78', 'US'],
#        ['26.0', '4', '98.00', '90.00', '2265.', '15.5', '73', 'Europe'],
#        ['30.0', '4', '88.00', '76.00', '2065.', '14.5', '71', 'Europe'],
#        ['15.0', '8', '302.0', '130.0', '4295.', '14.9', '77', 'US'],
#        ['19.0', '6', '232.0', '100.0', '2901.', '16.0', '74', 'US'],
#        ['18.5', '8', '360.0', '150.0', '3940.', '13.0', '79', 'US'],
#        ['17.5', '8', '305.0', '145.0', '3880.', '12.5', '77', 'US'],
#        ['15.5', '8', '400.0', '190.0', '4325.', '12.2', '77', 'US'],
#        ['30.0', '4', '111.0', '80.00', '2155.', '14.8', '77', 'US'],
#        ['13.0', '8', '440.0', '215.0', '4735.', '11.0', '73', 'US'],
#        ['39.1', '4', '79.00', '58.00', '1755.', '16.9', '81', 'Japan'],
#        ['16.0', '8', '302.0', '140.0', '4141.', '14.0', '74', 'US'],
#        ['23.7', '3', '70.00', '100.0', '2420.', '12.5', '80', 'Japan'],
# ...

# %%
# count array items in x_test array
x_test.size
# Out:
# 656

# %%
x_train.size + x_test.size + y_train.size + y_test.size
# Out:
# 3663
