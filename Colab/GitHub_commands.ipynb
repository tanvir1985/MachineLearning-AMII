# %% [markdown]
# Google Co-Lab notebook to allow team collaboration using Github.
#
# Why?
# If you save files in colab, it will simply overwrite the existing file, which is a problem if multiple users are working on the same file concurrently.  This same problem occurs if you use the *COLAB File - Save a copy in GitHub * function.

# %%
# authenticate
# get your GitHub token
# make a copy in google drive called /github/repo name
# go make your changes
# come back to this file and PUSH the changes into /github/repo

# see https://stackoverflow.com/questions/59454990/how-to-push-from-colab-to-github
# video https://www.simplilearn.com/tutorials/git-tutorial/git-push-command

# %%
# GitHub process key is Pull -> Edit -> Add -> Pull -> Commit -> Push
